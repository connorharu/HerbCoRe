# %% [markdown]
# ## Separating images
#
# In this notebook you are able to separate the herbarium images that you have under the same directory. By the end of it, your images will be separated in subfolders in three categories: exsiccatae, live images, and labels from herbariums.
# Please verify if all images have been correctly categorized.

# %%
from bibliotecas import *
from model_training import image_organizing

# %%
# change origin_folder "balanceado" for your actual folder
image_organizing(origin_folder='balanceado', destiny_folder='balanced-images-4')
